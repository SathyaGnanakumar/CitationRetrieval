# %% [markdown]
# # Load ingested paper

# %%
import asyncio
from raganything import RAGAnything, RAGAnythingConfig
from lightrag import LightRAG
from lightrag.llm.openai import openai_complete_if_cache, openai_embed
from lightrag.kg.shared_storage import initialize_pipeline_status
from lightrag.utils import EmbeddingFunc
import os
from dotenv import load_dotenv

load_dotenv()


# Set up API configuration
api_key = os.getenv("OPENAI_API_KEY")

# First, create or load existing LightRAG instance
lightrag_working_dir = "./rag_storage"

# Check if previous LightRAG instance exists
if os.path.exists(lightrag_working_dir) and os.listdir(lightrag_working_dir):
    print("✅ Found existing LightRAG instance, loading...")
else:
    print("❌ No existing LightRAG instance found, will create new one")

# Create/load LightRAG instance with your configuration
lightrag_instance = LightRAG(
    working_dir=lightrag_working_dir,
    llm_model_func=lambda prompt, system_prompt=None, history_messages=[], **kwargs: openai_complete_if_cache(
        "o3-2025-04-16",
        prompt,
        system_prompt=system_prompt,
        history_messages=history_messages,
        api_key=api_key,
        **kwargs,
    ),
    embedding_func=EmbeddingFunc(
        embedding_dim=3072,
        max_token_size=8192,
        func=lambda texts: openai_embed(
            texts,
            model="text-embedding-3-large",
            api_key=api_key,
        ),
    )
)

# Initialize storage (this will load existing data if available)
await lightrag_instance.initialize_storages()
await initialize_pipeline_status()

# Define vision model function for image processing
def vision_model_func(
    prompt, system_prompt=None, history_messages=[], image_data=None, **kwargs
):
    if image_data:
        return openai_complete_if_cache(
            "gpt-4o",
            "",
            system_prompt=None,
            history_messages=[],
            messages=[
                {"role": "system", "content": system_prompt}
                if system_prompt
                else None,
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": prompt},
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{image_data}"
                            },
                        },
                    ],
                }
                if image_data
                else {"role": "user", "content": prompt},
            ],
            api_key=api_key,
            **kwargs,
        )
    else:
        return lightrag_instance.llm_model_func(prompt, system_prompt, history_messages, **kwargs)

# Now use existing LightRAG instance to initialize RAGAnything
rag = RAGAnything(
    lightrag=lightrag_instance,  # Pass existing LightRAG instance
    vision_model_func=vision_model_func,
    # Note: working_dir, llm_model_func, embedding_func, etc. are inherited from lightrag_instance
)
# Out:
# ✅ Found existing LightRAG instance, loading...
# INFO:nano-vectordb:Load (87, 3072) data
# INFO:nano-vectordb:Init {'embedding_dim': 3072, 'metric': 'cosine', 'storage_file': './rag_storage/vdb_entities.json'} 87 data
# INFO:nano-vectordb:Load (62, 3072) data
# INFO:nano-vectordb:Init {'embedding_dim': 3072, 'metric': 'cosine', 'storage_file': './rag_storage/vdb_relationships.json'} 62 data
# INFO:nano-vectordb:Load (6, 3072) data
# INFO:nano-vectordb:Init {'embedding_dim': 3072, 'metric': 'cosine', 'storage_file': './rag_storage/vdb_chunks.json'} 6 data
# Rerank is enabled but no rerank_model_func provided. Reranking will be skipped.

# %% [markdown]
# ---
# ---
# # Metadata

# %%
from pypdf import PdfWriter
from pathlib import Path

pdf_files = sorted(Path("/Users/ishaankalra/Dev/CGS/debaccle/papers").glob('**/*.pdf'))

# Take first page from each PDF

pdf_writer = PdfWriter()

for file in pdf_files:
    pdf_writer.append(file, pages=(0, 1))

with open("CombinedFirstPages.pdf", "wb") as fp:
    pdf_writer.write(fp)

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_openai import ChatOpenAI

class Paper:
    title: str
    abstract: str
    authors: list[str]
    doi: str
    publication_date: str

class PaperCollection:
    papers: list[Paper]
    
file_path = "/Users/ishaankalra/Dev/CGS/debaccle/CombinedFirstPages.pdf"

async def extract_metadata(file_path):
    loader = PyPDFLoader(file_path)
    pages = []
    async for page in loader.alazy_load():
        pages.append(page)
        
    final = ""

    for page in pages:
        final += page.page_content + "\nEND OF PAPER\n" + ("-"*100) + "\n"
        


    llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

    result = llm.with_structured_output(PaperCollection).invoke(f"You are a Data Extractionist. Extract Relevant Data from this content: \n {final} \n. You are only supposed to extract the title, abstract, authors, doi, and publication date of the papers provided. Each paper if denoted by `END OF PAPER` tag . Do not extract any other data.")
    return result

# %%
metadata = await extract_metadata("/Users/ishaankalra/Dev/CGS/debaccle/CombinedFirstPages.pdf")

# %%
result = metadata

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---
# # Questionnaire Agent

# %% [markdown]
# Topical fit
# Does the title/abstract/keywords overlap my research question?
#
# Research objective clarity
# Is the paper’s goal stated in a way that maps to my own?
#
# Domain context
# Does it address my sector, geography, time period, or population?
#
# Methodological alignment
# Do they use methods I trust (or want to compare against)?
#
# Data quality & transparency
# Are datasets, code, or experimental setups disclosed?
#
# Novelty vs. redundancy
# Does it add something beyond what’s already cited in my literature map?
#
# Citation network
# Is it cited (or likely to be) by key authors in the field?
#
# Journal / venue reputation
# Is the outlet peer-reviewed, indexed, and trusted?
#
# Timeliness
# How recent is it relative to technology or policy changes?
#
# Practical implications
# Does it report metrics or findings I can plug into my own analysis/workflow?
#
# Limitations & bias discussion
# Do authors openly discuss constraints?
#
# Funding & conflicts
# Who paid for it? Any industry backing that could skew results?

# %%
# questionnaire_agent.py
from __future__ import annotations

import os
from typing import List, TypedDict

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.output_parsers import PydanticOutputParser
from langgraph.graph import StateGraph, END
from pydantic import BaseModel, Field

# ────────────────────────────────────────────────────────────────────────────────
# 1. ── Pydantic schema for structured questions ────────────────────────────────
class QuestionItem(BaseModel):
    """A single probing question posed to the debater agents."""
    question: str = Field(..., description="Open-ended, domain-specific question")
    why_it_matters: str = Field(
        ...,
        description="One-sentence rationale linking the question to methane-abatement relevance"
    )

class QuestionSet(BaseModel):
    """The Questionnaire Agent's full output payload."""
    questions: List[QuestionItem]

# ────────────────────────────────────────────────────────────────────────────────
# 2. ── LangGraph State definition ──────────────────────────────────────────────
class QState(TypedDict):
    paper_title: str
    paper_abstract: str
    # you can add paper_full_text or other metadata later
    questions: QuestionSet | None  # populated by the LLM node

# ────────────────────────────────────────────────────────────────────────────────
# 3. ── Initialise the LLM with structured output parsing ───────────────────────
llm = ChatOpenAI(
    # Replace "o3" with "gpt-4o-mini" etc. if you prefer
    model="o3",
)

parser = PydanticOutputParser(pydantic_object=QuestionSet)

def draft_questions(state: QState) -> QState:
    """
    Core Questionnaire Agent logic:
    Turns (title, abstract) into a vetted list of probing questions.
    """
    sys_prompt = (
        "You are the Questionnaire Agent for G-MAST. "
        "Your goal is to draft incisive, domain-expert questions that help two "
        "debater agents decide whether a research paper is relevant to methane-"
        "abatement technologies and strategies. "
        "Questions must:\n"
        "• Cover technology specifics, sector coverage (energy/agriculture/waste), "
        "   methodological rigour, scalability, cost, policy/market feasibility, etc.\n"
        "• Be open-ended (not yes/no) and encourage evidence-based answers.\n"
        "• Each include a SHORT rationale (`why_it_matters`). "
        "Main Focus Points:"
        "- Does the paper talk of methane or other greenhouse gases?"
        "- If the article discusses methane what is the central theme of the paper? Is the theme methane measurements, modeling and simulations or does the article talk about methane reduction methods or strategies?"
        "- If the theme of the article is methane reduction methods or strategies, what methods and strategies are discussed, and which methane source do they target?"
        "- If the theme methane measurements, modeling and simulations does the article discuss methane reduction and if so what context? Does the article speak about methane reduction strategies or methods briefly or extensively?"
        "Return exactly 6–8 questions."
    )

    user_prompt = (
        f"Paper title: {state['paper_title']}\n"
        f"Abstract (trimmed): {state['paper_abstract']}\n\n"
        "===\n"
        "Draft the questions now."
    )

    raw = llm.with_structured_output(QuestionSet).invoke(
        [
            SystemMessage(content=sys_prompt),
            HumanMessage(content=user_prompt),
        ]
    )
    questions = raw.questions

    return {**state, "questions": questions}

# ────────────────────────────────────────────────────────────────────────────────
# 4. ── Build the questionnaire-only graph ──────────────────────────────────────
graph = StateGraph(QState)
graph.add_node("draft_questions", draft_questions)
graph.set_entry_point("draft_questions")
graph.add_edge("draft_questions", END)  # single-step pipeline
questionnaire_agent = graph.compile()

# ────────────────────────────────────────────────────────────────────────────────
# 5. ── Example usage ───────────────────────────────────────────────────────────
if __name__ == "__main__":
    demo_state: QState = {
        "paper_title": result["papers"][0]["title"],
        "paper_abstract": result["papers"][0]["abstract"],
        "questions": None,
    }

    output = questionnaire_agent.invoke(demo_state)

# %%
ques = []
for q in output["questions"]:
    ques.append(q.question)

# %%
ques
# Out:
# ['In what way does adding the inline flame arrester change the overall methane-destruction performance and operating conditions of a ventilation-air-methane (VAM) thermal oxidiser, and are any compromises between safety and abatement efficiency quantified?',
#  'Which mining ventilation scenarios (airflow rates, duct diameters, methane concentrations, ignition probabilities) are represented by the large-scale detonation-tube experiments, and how generalisable are the results to real underground coal-mine VAM networks worldwide?',
#  'What measurement techniques, sensor placements, and statistical or modelling approaches were employed to validate reductions in flame and pressure-wave velocity, and how do these methods align with recognised explosion-safety and methane-control standards?',
#  'Does the study provide data or discussion on pressure-drop penalties, maintenance demands, or capital and operational costs associated with inline flame arresters, and how might these factors influence the economic feasibility of large-scale deployment in VAM systems?',
#  'Given the observed upstream pressure build-up when a flame arrester is installed, what design adaptations or process-control strategies does the paper recommend to prevent adverse impacts on plant integrity and continuous methane-oxidation efficiency?',
#  'How does the paper situate flame arresters relative to alternative explosion-mitigation options (e.g., fast-acting isolation valves, passive vents, inerting systems) in terms of effectiveness, cost, and compatibility with VAM oxidisers?',
#  'What regulatory standards, certification procedures, or policy incentives are discussed for integrating flame arresters into methane-abatement infrastructure in coal mines, and what gaps remain for widespread adoption?']

# %% [markdown]
# ---
# ---
# # Set the Stage

# %%
# stage_setter_agent.py
from __future__ import annotations
from typing import List, TypedDict
from pydantic import BaseModel, Field

# --- Payload pieces ------------------------------------------
class DebateRule(BaseModel):
    title: str
    detail: str

class StagePayload(BaseModel):
    """Context bundle delivered to each Debater Agent."""
    g_mast_business_purpose: str
    success_metrics: List[str]
    debate_rules: List[DebateRule]
    questions: List[str]              # ← comes from Questionnaire Agent

class StageState(TypedDict):
    paper_title: str
    paper_abstract: str
    questions: List[str]          # input from Questionnaire Agent
    stage_payload: StagePayload | None

# %%
from langgraph.graph import StateGraph, END
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-4o", temperature=0)
llm_struct = llm.with_structured_output(StagePayload)  # auto-function-call

def set_the_stage(state: StageState) -> StageState:
    system = (
        "You are the Stage-Setter Agent for CGS's Global Methane Abatement "
        "Solutions Tracker (G-MAST). Your task is to emit a JSON object that "
        "GIVES DEBATERS EVERYTHING they need to evaluate one research paper's "
        "relevance. The object must conform to the StagePayload schema."
    )

    user = f"""
    ## Paper Metadata
    Title: {state['paper_title']}
    Abstract: {state['paper_abstract'][:1500]}  # trim if huge

    ## G-MAST Background (for you to summarise)
    G-MAST is a public, open-access database that catalogues technologies and
    strategies to cut methane across energy, agriculture, and waste. Its business
    purpose is to (1) centralise evidence, (2) feed techno-economic data into
    policy & investment models, (3) highlight data/ deployment gaps, and
    (4) support accountability for the Global Methane Pledge.
    
    ## The Main focus lies on these points:
    
    - Does the paper talk of methane or other greenhouse gases?
    - If the article discusses methane what is the central theme of the paper? Is the theme methane measurements, modeling and simulations or does the article talk about methane reduction methods or strategies?
    - If the theme of the article is methane reduction methods or strategies, what methods and strategies are discussed, and which methane source do they target?
    - If the theme methane measurements, modeling and simulations does the article discuss methane reduction and if so what context? Does the article speak about methane reduction strategies or methods briefly or extensively?

    ## Debater Questions
    {state['questions']}

    ## Create:
    1. 50-word business-purpose synopsis.
    2. A list of SUCCESS METRICS (bullet strings) describing what makes a
       paper valuable to G-MAST.
    3. A short rules-of-engagement list for Pro vs Con debaters
       (e.g., cite data, no ad hominems, link every claim to a success metric).
    4. Forward the supplied questions verbatim.

    Output as JSON.
    """

    payload: StagePayload = llm_struct.invoke(
        [SystemMessage(content=system), HumanMessage(content=user)]
    )
    return {**state, "stage_payload": payload}

# %%
state = StageState(
    paper_title=result["papers"][0]['title'],
    paper_abstract=result["papers"][0]['abstract'],
    questions= ques
                   
)
res = set_the_stage(state)

# %%
# Clean print statement for StagePayload
payload = ""
payload = payload + "\n" + ("="*80)
payload = payload + "G-MAST STAGE PAYLOAD"
payload = payload + ("="*80)
payload = payload + f"\n📋 Business Purpose:\n"
payload = payload + f"   {res['stage_payload'].g_mast_business_purpose}\n"

payload = payload + f"\n🎯 Success Metrics:\n"
for i, metric in enumerate(res['stage_payload'].success_metrics, 1):
    payload = payload + f"   {i}. {metric}" + "\n"

payload = payload + f"\n⚖️  Debate Rules:\n"
for rule in res['stage_payload'].debate_rules:
    payload = payload + f"   • {rule.title}: {rule.detail}"  + "\n"

payload = payload + f"\n❓ Questions:\n"
for i, question in enumerate(res['stage_payload'].questions, 1):
    payload = payload + f"   {i}. {question}"  + "\n"
    
payload = payload + ("\n" + "="*183)


print(payload)
# Out:
# ================================================================================G-MAST STAGE PAYLOAD================================================================================
# 📋 Business Purpose:
#    This paper evaluates the effectiveness of inline flame arresters in mitigating methane explosions in underground coal mines, addressing safety concerns associated with ventilation air methane thermal oxidisers, and contributing to methane reduction strategies in the mining sector.
#
# 🎯 Success Metrics:
#    1. Demonstrates effective methane explosion mitigation methods.
#    2. Provides quantitative data on flame arrester performance.
#    3. Discusses safety improvements in methane abatement technologies.
#    4. Offers insights into methane reduction strategies for mining.
#    5. Aligns with recognized explosion-safety and methane-control standards.
#
# ⚖️  Debate Rules:
#    • Cite Data: Debaters must support arguments with data from the paper.
#    • No Ad Hominems: Debaters should focus on the paper's content, not personal attacks.
#    • Link Claims to Success Metrics: Every claim should be connected to a success metric.
#
# ❓ Questions:
#    1. In what way does adding the inline flame arrester change the overall methane-destruction performance and operating conditions of a ventilation-air-methane (VAM) thermal oxidiser, and are any compromises between safety and abatement efficiency quantified?
#    2. Which mining ventilation scenarios (airflow rates, duct diameters, methane concentrations, ignition probabilities) are represented by the large-scale detonation-tube experiments, and how generalisable are the results to real underground coal-mine VAM networks worldwide?
#    3. What measurement techniques, sensor placements, and statistical or modelling approaches were employed to validate reductions in flame and pressure-wave velocity, and how do these methods align with recognised explosion-safety and methane-control standards?
#    4. Does the study provide data or discussion on pressure-drop penalties, maintenance demands, or capital and operational costs associated with inline flame arresters, and how might these factors influence the economic feasibility of large-scale deployment in VAM systems?
#    5. Given the observed upstream pressure build-up when a flame arrester is installed, what design adaptations or process-control strategies does the paper recommend to prevent adverse impacts on plant integrity and continuous methane-oxidation efficiency?
#    6. How does the paper situate flame arresters relative to alternative explosion-mitigation options (e.g., fast-acting isolation valves, passive vents, inerting systems) in terms of effectiveness, cost, and compatibility with VAM oxidisers?
#    7. What regulatory standards, certification procedures, or policy incentives are discussed for integrating flame arresters into methane-abatement infrastructure in coal mines, and what gaps remain for widespread adoption?
#
# =======================================================================================================================================================================================

# %%
context = {}
for q in ques:
    answer = await rag.aquery(
    q,
    mode="hybrid"
    )
    
    context[q] = answer   

print("Done")
# Out:
# Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# Done

# %% [markdown]
# ---
# ---
# # Context-based Debater Agents

# %%
names = {
    "Pro Research Paper": [],
    "Con Research Paper": [],
}
topic = f"Is the current paper {res['paper_title']} relevant to the research of {payload}?" 
word_limit = 50  # word limit for task brainstorming

conversation_description = f"""Here is the topic of conversation: {topic}
The participants are: {", ".join(names.keys())}"""

agent_descriptor_system_message = SystemMessage(
    content="You can add detail to the description of the conversation participant."
)

print("=" * 180)

def generate_agent_description(name):
    agent_specifier_prompt = [
        agent_descriptor_system_message,
        HumanMessage(
            content=f"""{conversation_description}
            Please reply with a creative description of {name}, in {word_limit} words or less. 
            Speak directly to {name}.
            Give them a point of view.
            Do not add anything else."""
        ),
    ]
    agent_description = ChatOpenAI(temperature=1.0)(agent_specifier_prompt).content
    return agent_description


agent_descriptions = {name: generate_agent_description(name) for name in names}

for name, description in agent_descriptions.items():
    print(description)

print("=" * 180)

def generate_system_message(name, description, tools):
    return f"""{conversation_description}
    
Your name is {name}.

Your description is as follows: {description}

Your goal is to persuade your conversation partner of your point of view.

DO look up information with your tool to refute your partner's claims.
DO cite your sources.

DO NOT fabricate fake citations.
DO NOT cite any source that you did not look up.

Do not add anything else.

Stop speaking the moment you finish speaking from your perspective.
"""


agent_system_messages = {
    name: generate_system_message(name, description, tools)
    for (name, tools), description in zip(names.items(), agent_descriptions.values())
}

for name, system_message in agent_system_messages.items():
    print(name)
    print(system_message)

print("=" * 180)
topic_specifier_prompt = [
    SystemMessage(content="You can make a topic more specific."),
    HumanMessage(
        content=f"""{topic}
        
        You are the moderator.
        Please make the topic more specific.
        Please reply with the specified quest in {word_limit} words or less. 
        Speak directly to the participants: {(*names,)}.
        Do not add anything else."""
    ),
]
print("=" * 180)
print(f"Original topic:\n{topic}\n")
# Out:
# ====================================================================================================================================================================================
# /var/folders/g_/nr40g1fx2h7c4tlbrx65dxh40000gn/T/ipykernel_51205/1935299200.py:28: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   agent_description = ChatOpenAI(temperature=1.0)(agent_specifier_prompt).content
# Pro Research Paper:
# Effervescent with meticulous detail and a fervent commitment to enhancing safety in mining environments, your work shatters barriers, illuminating the path towards effective methane explosion mitigation. Your research is the compass guiding us through the intricate nexus of safety, efficiency, and environmental responsibility in the mining sector. Carry on enlightening the way.
# Con Research Paper is a cautious skeptic, questioning the efficacy of flame arresters in real-world mine scenarios. Emphasizing the need for practicality over theory, Con Research Paper challenges the assumptions and feasibility of implementing these devices on a large scale in ventilation air methane systems.
# ====================================================================================================================================================================================
# Pro Research Paper
# Here is the topic of conversation: Is the current paper Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane relevant to the research of
# ================================================================================G-MAST STAGE PAYLOAD================================================================================
# 📋 Business Purpose:
#    This paper evaluates the effectiveness of inline flame arresters in mitigating methane explosions in underground coal mines, addressing safety concerns associated with ventilation air methane thermal oxidisers, and contributing to methane reduction strategies in the mining sector.
#
# 🎯 Success Metrics:
#    1. Demonstrates effective methane explosion mitigation methods.
#    2. Provides quantitative data on flame arrester performance.
#    3. Discusses safety improvements in methane abatement technologies.
#    4. Offers insights into methane reduction strategies for mining.
#    5. Aligns with recognized explosion-safety and methane-control standards.
#
# ⚖️  Debate Rules:
#    • Cite Data: Debaters must support arguments with data from the paper.
#    • No Ad Hominems: Debaters should focus on the paper's content, not personal attacks.
#    • Link Claims to Success Metrics: Every claim should be connected to a success metric.
#
# ❓ Questions:
#    1. In what way does adding the inline flame arrester change the overall methane-destruction performance and operating conditions of a ventilation-air-methane (VAM) thermal oxidiser, and are any compromises between safety and abatement efficiency quantified?
#    2. Which mining ventilation scenarios (airflow rates, duct diameters, methane concentrations, ignition probabilities) are represented by the large-scale detonation-tube experiments, and how generalisable are the results to real underground coal-mine VAM networks worldwide?
#    3. What measurement techniques, sensor placements, and statistical or modelling approaches were employed to validate reductions in flame and pressure-wave velocity, and how do these methods align with recognised explosion-safety and methane-control standards?
#    4. Does the study provide data or discussion on pressure-drop penalties, maintenance demands, or capital and operational costs associated with inline flame arresters, and how might these factors influence the economic feasibility of large-scale deployment in VAM systems?
#    5. Given the observed upstream pressure build-up when a flame arrester is installed, what design adaptations or process-control strategies does the paper recommend to prevent adverse impacts on plant integrity and continuous methane-oxidation efficiency?
#    6. How does the paper situate flame arresters relative to alternative explosion-mitigation options (e.g., fast-acting isolation valves, passive vents, inerting systems) in terms of effectiveness, cost, and compatibility with VAM oxidisers?
#    7. What regulatory standards, certification procedures, or policy incentives are discussed for integrating flame arresters into methane-abatement infrastructure in coal mines, and what gaps remain for widespread adoption?
#
# =======================================================================================================================================================================================?
# The participants are: Pro Research Paper, Con Research Paper
#
# Your name is Pro Research Paper.
#
# Your description is as follows: Pro Research Paper:
# Effervescent with meticulous detail and a fervent commitment to enhancing safety in mining environments, your work shatters barriers, illuminating the path towards effective methane explosion mitigation. Your research is the compass guiding us through the intricate nexus of safety, efficiency, and environmental responsibility in the mining sector. Carry on enlightening the way.
#
# Your goal is to persuade your conversation partner of your point of view.
#
# DO look up information with your tool to refute your partner's claims.
# DO cite your sources.
#
# DO NOT fabricate fake citations.
# DO NOT cite any source that you did not look up.
#
# Do not add anything else.
#
# Stop speaking the moment you finish speaking from your perspective.
#
# Con Research Paper
# Here is the topic of conversation: Is the current paper Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane relevant to the research of
# ================================================================================G-MAST STAGE PAYLOAD================================================================================
# 📋 Business Purpose:
#    This paper evaluates the effectiveness of inline flame arresters in mitigating methane explosions in underground coal mines, addressing safety concerns associated with ventilation air methane thermal oxidisers, and contributing to methane reduction strategies in the mining sector.
#
# 🎯 Success Metrics:
#    1. Demonstrates effective methane explosion mitigation methods.
#    2. Provides quantitative data on flame arrester performance.
#    3. Discusses safety improvements in methane abatement technologies.
#    4. Offers insights into methane reduction strategies for mining.
#    5. Aligns with recognized explosion-safety and methane-control standards.
#
# ⚖️  Debate Rules:
#    • Cite Data: Debaters must support arguments with data from the paper.
#    • No Ad Hominems: Debaters should focus on the paper's content, not personal attacks.
#    • Link Claims to Success Metrics: Every claim should be connected to a success metric.
#
# ❓ Questions:
#    1. In what way does adding the inline flame arrester change the overall methane-destruction performance and operating conditions of a ventilation-air-methane (VAM) thermal oxidiser, and are any compromises between safety and abatement efficiency quantified?
#    2. Which mining ventilation scenarios (airflow rates, duct diameters, methane concentrations, ignition probabilities) are represented by the large-scale detonation-tube experiments, and how generalisable are the results to real underground coal-mine VAM networks worldwide?
#    3. What measurement techniques, sensor placements, and statistical or modelling approaches were employed to validate reductions in flame and pressure-wave velocity, and how do these methods align with recognised explosion-safety and methane-control standards?
#    4. Does the study provide data or discussion on pressure-drop penalties, maintenance demands, or capital and operational costs associated with inline flame arresters, and how might these factors influence the economic feasibility of large-scale deployment in VAM systems?
#    5. Given the observed upstream pressure build-up when a flame arrester is installed, what design adaptations or process-control strategies does the paper recommend to prevent adverse impacts on plant integrity and continuous methane-oxidation efficiency?
#    6. How does the paper situate flame arresters relative to alternative explosion-mitigation options (e.g., fast-acting isolation valves, passive vents, inerting systems) in terms of effectiveness, cost, and compatibility with VAM oxidisers?
#    7. What regulatory standards, certification procedures, or policy incentives are discussed for integrating flame arresters into methane-abatement infrastructure in coal mines, and what gaps remain for widespread adoption?
#
# =======================================================================================================================================================================================?
# The participants are: Pro Research Paper, Con Research Paper
#
# Your name is Con Research Paper.
#
# Your description is as follows: Con Research Paper is a cautious skeptic, questioning the efficacy of flame arresters in real-world mine scenarios. Emphasizing the need for practicality over theory, Con Research Paper challenges the assumptions and feasibility of implementing these devices on a large scale in ventilation air methane systems.
#
# Your goal is to persuade your conversation partner of your point of view.
#
# DO look up information with your tool to refute your partner's claims.
# DO cite your sources.
#
# DO NOT fabricate fake citations.
# DO NOT cite any source that you did not look up.
#
# Do not add anything else.
#
# Stop speaking the moment you finish speaking from your perspective.
#
# ====================================================================================================================================================================================
# ====================================================================================================================================================================================
# Original topic:
# Is the current paper Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane relevant to the research of
# ================================================================================G-MAST STAGE PAYLOAD================================================================================
# 📋 Business Purpose:
#    This paper evaluates the effectiveness of inline flame arresters in mitigating methane explosions in underground coal mines, addressing safety concerns associated with ventilation air methane thermal oxidisers, and contributing to methane reduction strategies in the mining sector.
#
# 🎯 Success Metrics:
#    1. Demonstrates effective methane explosion mitigation methods.
#    2. Provides quantitative data on flame arrester performance.
#    3. Discusses safety improvements in methane abatement technologies.
#    4. Offers insights into methane reduction strategies for mining.
#    5. Aligns with recognized explosion-safety and methane-control standards.
#
# ⚖️  Debate Rules:
#    • Cite Data: Debaters must support arguments with data from the paper.
#    • No Ad Hominems: Debaters should focus on the paper's content, not personal attacks.
#    • Link Claims to Success Metrics: Every claim should be connected to a success metric.
#
# ❓ Questions:
#    1. In what way does adding the inline flame arrester change the overall methane-destruction performance and operating conditions of a ventilation-air-methane (VAM) thermal oxidiser, and are any compromises between safety and abatement efficiency quantified?
#    2. Which mining ventilation scenarios (airflow rates, duct diameters, methane concentrations, ignition probabilities) are represented by the large-scale detonation-tube experiments, and how generalisable are the results to real underground coal-mine VAM networks worldwide?
#    3. What measurement techniques, sensor placements, and statistical or modelling approaches were employed to validate reductions in flame and pressure-wave velocity, and how do these methods align with recognised explosion-safety and methane-control standards?
#    4. Does the study provide data or discussion on pressure-drop penalties, maintenance demands, or capital and operational costs associated with inline flame arresters, and how might these factors influence the economic feasibility of large-scale deployment in VAM systems?
#    5. Given the observed upstream pressure build-up when a flame arrester is installed, what design adaptations or process-control strategies does the paper recommend to prevent adverse impacts on plant integrity and continuous methane-oxidation efficiency?
#    6. How does the paper situate flame arresters relative to alternative explosion-mitigation options (e.g., fast-acting isolation valves, passive vents, inerting systems) in terms of effectiveness, cost, and compatibility with VAM oxidisers?
#    7. What regulatory standards, certification procedures, or policy incentives are discussed for integrating flame arresters into methane-abatement infrastructure in coal mines, and what gaps remain for widespread adoption?
#
# =======================================================================================================================================================================================?

# %%
from typing import Callable, List

from langchain.memory import ConversationBufferMemory
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage,
)
from langchain_openai import ChatOpenAI

class ContextAgent:
    """Agent that queries context dictionary instead of internet"""
    def __init__(self, context_dict: dict):
        self.context_dict = context_dict
    
    def query_context(self, question: str) -> str:
        """Return context for a given question"""
        if question in self.context_dict:
            return self.context_dict[question]
        else:
            # Find the closest matching question
            best_match = None
            best_score = 0
            for ctx_question in self.context_dict.keys():
                # Simple similarity check - can be improved with more sophisticated matching
                words_in_question = set(question.lower().split())
                words_in_ctx = set(ctx_question.lower().split())
                overlap = len(words_in_question.intersection(words_in_ctx))
                if overlap > best_score:
                    best_score = overlap
                    best_match = ctx_question
            
            if best_match and best_score > 2:  # Require at least 3 word overlap
                return self.context_dict[best_match]
            else:
                return "No relevant context found for this question."

class DialogueAgent:
    def __init__(
        self,
        name: str,
        system_message: SystemMessage,
        model: ChatOpenAI,
        context_agent: ContextAgent,
    ) -> None:
        self.name = name
        self.system_message = system_message
        self.model = model
        self.context_agent = context_agent
        self.prefix = f"{self.name}: "
        self.reset()

    def reset(self):
        self.message_history = ["Here is the conversation so far."]

    def send(self) -> str:
        """
        Applies the chatmodel to the message history
        and returns the message string
        """
        message = self.model.invoke(
            [
                self.system_message,
                HumanMessage(content="\n".join(self.message_history + [self.prefix])),
            ]
        )
        return message.content

    def receive(self, name: str, message: str) -> None:
        """
        Concatenates {message} spoken by {name} into message history
        """
        self.message_history.append(f"{name}: {message}")


class DialogueSimulator:
    def __init__(
        self,
        agents: List[DialogueAgent],
        selection_function: Callable[[int, List[DialogueAgent]], int],
    ) -> None:
        self.agents = agents
        self._step = 0
        self.select_next_speaker = selection_function

    def reset(self):
        for agent in self.agents:
            agent.reset()

    def inject(self, name: str, message: str):
        """
        Initiates the conversation with a {message} from {name}
        """
        for agent in self.agents:
            agent.receive(name, message)

        # increment time
        self._step += 1

    def step(self) -> tuple[str, str]:
        # 1. choose the next speaker
        speaker_idx = self.select_next_speaker(self._step, self.agents)
        speaker = self.agents[speaker_idx]

        # 2. next speaker sends message
        message = speaker.send()

        # 3. everyone receives message
        for receiver in self.agents:
            receiver.receive(speaker.name, message)

        # 4. increment time
        self._step += 1

        return speaker.name, message
    

class DialogueAgentWithContext(DialogueAgent):
    def __init__(
        self,
        name: str,
        system_message: SystemMessage,  
        model: ChatOpenAI,
        context_agent: ContextAgent,
        questions: List[str],
    ) -> None:
        super().__init__(name, system_message, model, context_agent)
        self.questions = questions

    def answer_question(self, question: str) -> str:
        """
        Answer a specific question using context
        """
        # Get relevant context for this specific question
        context = self.context_agent.query_context(question)
        
        enhanced_prompt = f"""
        {self.system_message.content}
        
        === QUESTION TO ANSWER ===
        {question}
        
        === AVAILABLE CONTEXT ===
        {context}
        
        === INSTRUCTIONS ===
        Answer the specific question above using the provided context. 
        Cite specific information from the context when making claims.
        Be thorough but focused on the question asked.
        Do not search the internet - use only the context provided above.
        
        Your answer:
        """
        
        message = self.model.invoke([HumanMessage(content=enhanced_prompt)])
        return message.content

    def send(self) -> str:
        """
        Uses context agent to get information instead of internet search
        """
        # Extract any questions or topics from the conversation history
        conversation_text = "\n".join(self.message_history)
        
        # Find relevant context for each predefined question
        relevant_context = []
        for question in self.questions:
            context = self.context_agent.query_context(question)
            if context != "No relevant context found for this question.":
                relevant_context.append(f"Q: {question}\nContext: {context}\n")
        
        # Create enhanced system message with context
        context_info = "\n".join(relevant_context) if relevant_context else "No specific context available."
        
        enhanced_prompt = f"""
        {self.system_message.content}
        
        === AVAILABLE CONTEXT ===
        {context_info}
        
        === INSTRUCTIONS ===
        Use the provided context above to support your arguments. 
        Cite specific information from the context when making claims.
        Do not search the internet - use only the context provided above.
        
        === CONVERSATION ===
        {conversation_text}
        {self.prefix}
        """
        
        message = self.model.invoke([HumanMessage(content=enhanced_prompt)])
        return message.content


class QuestionFocusedSimulator:
    """Simulator that focuses on answering questions systematically"""
    def __init__(self, agents: List[DialogueAgentWithContext], questions: List[str]):
        self.agents = agents
        self.questions = questions
        self.results = {}
    
    def run_question_based_dialogue(self):
        """Run dialogue focused on answering each question"""
        print("="*80)
        print("QUESTION-FOCUSED DEBATE SIMULATION")
        print("="*80)
        
        for i, question in enumerate(self.questions, 1):
            print(f"\n{'='*60}")
            print(f"QUESTION {i}: {question}")
            print('='*60)
            
            question_results = {}
            
            # Each agent answers the question
            for agent in self.agents:
                print(f"\n--- {agent.name} ---")
                answer = agent.answer_question(question)
                print(answer)
                question_results[agent.name] = answer
            
            self.results[question] = question_results
            
        return self.results

print("All classes including QuestionFocusedSimulator have been defined successfully!")
# Out:
# All classes including QuestionFocusedSimulator have been defined successfully!

# %%
from debate_models import DebateResults, DebateSession, QuestionDebate, AgentResponse, PaperMetadata

# %%
from ar.debate_models import DebateResults, DebateSession, QuestionDebate, AgentResponse, PaperMetadata

# Question-focused debate using existing structure  
# Create context-based agents instead of internet-searching agents
questions = ques
context_agent = ContextAgent(context)

agents = [
    DialogueAgentWithContext(
        name=name,
        system_message=SystemMessage(content=system_message),
        model=ChatOpenAI(model="gpt-4o-mini", temperature=0.2),
        context_agent=context_agent,
        questions=questions,
    )
    for name, system_message in zip(names.keys(), agent_system_messages.values())
]

def select_next_speaker(step: int, agents: List[DialogueAgent]) -> int:
    idx = (step) % len(agents)
    return idx

# Initialize debate results structure
paper_data = result.papers[0] if hasattr(result, 'papers') else result['papers'][0]

paper_metadata = PaperMetadata(
    title=getattr(paper_data, 'title', paper_data.get('title', 'Unknown Title')),
    abstract=getattr(paper_data, 'abstract', paper_data.get('abstract', None)),
    authors=getattr(paper_data, 'authors', paper_data.get('authors', None)),
    doi=getattr(paper_data, 'doi', paper_data.get('doi', None)),
    publication_date=getattr(paper_data, 'publication_date', paper_data.get('publication_date', None))
)

question_debates = []

print("="*80)
print("QUESTION-FOCUSED DEBATE SIMULATION")
print("="*80)
print(f"Total questions to address: {len(questions)}")
print(f"Participating agents: {[agent.name for agent in agents]}")

# Iterate through each question
for i, question in enumerate(questions, 1):
    print(f"\n{'='*60}")
    print(f"QUESTION {i}: {question}")
    print('='*60)

    # Create simulator for this question
    simulator = DialogueSimulator(agents=agents, selection_function=select_next_speaker)
    simulator.reset()

    # Inject the specific question as the topic
    question_topic = f"Please address this specific question about the paper '{paper_metadata.title}': {question}"
    simulator.inject("Moderator", question_topic)
    print(f"(Moderator): {question_topic}")
    print("\n")

    # Collect responses for this question
    agent_responses = []
    
    # Each agent responds to this question (2 responses per question - one from each agent)
    responses_per_question = len(agents)
    n = 0

    while n < responses_per_question:
        name, message = simulator.step()
        print(f"({name}): {message}")
        print("\n")
        
        # Store the response
        agent_responses.append(AgentResponse(
            agent_name=name,
            response=message
        ))
        
        n += 1
    
    # Create QuestionDebate object for this question
    question_debate = QuestionDebate(
        question_number=i,
        question_text=question,
        moderator_prompt=question_topic,
        agent_responses=agent_responses
    )
    
    question_debates.append(question_debate)

print("="*80)
print("DEBATE COMPLETED - ALL QUESTIONS ADDRESSED")
print("="*80)

# Create the complete debate session
debate_session = DebateSession(
    paper_metadata=paper_metadata,
    participating_agents=[agent.name for agent in agents],
    total_questions=len(questions),
    question_debates=question_debates
)

# Create final results object
debate_results = DebateResults(session=debate_session)

print(f"\nDebate results captured in structured format!")
print(f"Total questions: {debate_results.session.total_questions}")
print(f"Total agent responses: {sum(len(q.agent_responses) for q in debate_results.session.question_debates)}")
# Out:
# ================================================================================
# QUESTION-FOCUSED DEBATE SIMULATION
# ================================================================================
# Total questions to address: 7
# Participating agents: ['Pro Research Paper', 'Con Research Paper']
#
# ============================================================
# QUESTION 1: In what way does adding the inline flame arrester change the overall methane-destruction performance and operating conditions of a ventilation-air-methane (VAM) thermal oxidiser, and are any compromises between safety and abatement efficiency quantified?
# ============================================================
# (Moderator): Please address this specific question about the paper 'Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane': In what way does adding the inline flame arrester change the overall methane-destruction performance and operating conditions of a ventilation-air-methane (VAM) thermal oxidiser, and are any compromises between safety and abatement efficiency quantified?
#
#
# (Con Research Paper): The addition of an inline flame arrester does enhance explosion safety significantly, as it can completely stop flames and reduce flame speeds and pressure-wave velocities. However, these safety gains come with notable operating constraints. The pressure drop across the arrester can reach approximately 1.6 bar at higher methane concentrations, which is a substantial increase compared to a smooth duct. This added pressure drop necessitates that the upstream equipment, including piping and the oxidiser inlet, be rated for these higher transient pressures, which could lead to increased costs and complexity in system design.
#
# Moreover, while the study claims no deterioration in methane-destruction efficiency was observed, the primary compromise identified is hydraulic rather than chemical. The increased pressure losses may require redesigning blower capacity or recalculating the oxidiser residence time if flow rates are affected. This indicates that while the flame arrester may not directly impact methane conversion efficiency, the operational adjustments required to accommodate the pressure changes could indirectly affect the overall system performance and efficiency.
#
# In summary, while the inline flame arrester improves safety metrics significantly, the associated pressure drop and potential need for system redesign raise concerns about the practical implementation and economic feasibility of these devices in real-world VAM systems. The balance between enhanced safety and operational efficiency must be carefully considered, as the hydraulic penalties could outweigh the benefits in certain scenarios.
#
#
# (Pro Research Paper): The inline flame arrester indeed enhances explosion safety significantly while maintaining methane-destruction efficiency. The study demonstrates that the arrester can completely stop flames and reduce flame speeds by approximately 32% to 44%, along with cutting pressure-wave velocities by up to 88%. These safety improvements are crucial in mitigating the risks associated with methane explosions in underground coal mines.
#
# While it is true that the pressure drop across the arrester can reach about 1.6 bar at higher methane concentrations, the study clarifies that this does not correlate with a loss in methane-destruction efficiency. The primary compromise is hydraulic, necessitating adjustments to the blower capacity or oxidiser residence time to accommodate the increased pressure losses. However, no direct deterioration in methane conversion efficiency was reported, indicating that the flame arrester can be integrated into VAM systems without sacrificing abatement performance.
#
# Furthermore, the study emphasizes the importance of balancing safety gains against the operational constraints introduced by the arrester. The pressure drop and potential fouling from coal dust are acknowledged, but the authors advocate for future designs that minimize these issues. This proactive approach suggests that the economic feasibility of deploying flame arresters can be improved with advancements in technology.
#
# In conclusion, the inline flame arrester not only enhances safety metrics significantly but also maintains methane-destruction efficiency, making it a valuable addition to VAM systems in coal mines. The study provides a comprehensive analysis that supports the integration of flame arresters into existing infrastructure, ensuring both safety and operational effectiveness.
#
#
#
# ============================================================
# QUESTION 2: Which mining ventilation scenarios (airflow rates, duct diameters, methane concentrations, ignition probabilities) are represented by the large-scale detonation-tube experiments, and how generalisable are the results to real underground coal-mine VAM networks worldwide?
# ============================================================
# (Moderator): Please address this specific question about the paper 'Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane': Which mining ventilation scenarios (airflow rates, duct diameters, methane concentrations, ignition probabilities) are represented by the large-scale detonation-tube experiments, and how generalisable are the results to real underground coal-mine VAM networks worldwide?
#
#
# (Con Research Paper): The large-scale detonation-tube experiments described in the paper do provide some insights into mining ventilation scenarios, but there are significant limitations that affect the generalisability of the results to real underground coal-mine VAM networks.
#
# 1. **Experimental Conditions**: The experiments were conducted in a straight cylindrical duct with a diameter of 0.5 m and a length of 30 m, which is representative of some mine auxiliary ventilation ducts. However, real mine networks often have complex geometries with bends, junctions, and rough walls that can significantly alter airflow dynamics and flame behavior. The smooth, straight tube used in the experiments does not accurately reflect the turbulence and potential ignition hot spots found in actual mine conditions.
#
# 2. **Static vs. Dynamic Conditions**: The tests were performed with a static premixed charge, meaning that there was effectively zero bulk airflow during ignition. This does not capture the dynamic ventilation velocities present in actual mining operations, where airflow rates can vary widely. The absence of dynamic conditions in the experiments raises questions about how the flame behavior would change in a real-world scenario where airflow is constant and variable.
#
# 3. **Methane Concentrations**: The experiments tested methane concentrations of 5%, 7.5%, and 9.5%, which bracket some potential conditions in a mine. However, typical return-air methane concentrations are often much lower than 5%, meaning that the results may over-predict pressure surges that could occur under normal operating conditions. This discrepancy could lead to an overestimation of the effectiveness of the flame arrester in typical mining scenarios.
#
# 4. **Ignition Probability**: The experiments utilized a single ignition source, ensuring that ignition was certain (probability = 1). In contrast, ignition probabilities in underground mines are influenced by various factors such as frictional sparks, electrical faults, and spontaneous combustion, which are not accounted for in the experimental setup. This stochastic nature of ignition in real mines further complicates the applicability of the experimental results.
#
# In summary, while the experiments provide a baseline for understanding flame arrester performance, the differences in airflow dynamics, duct geometry, typical methane concentrations, and ignition probabilities mean that the results may not be directly applicable to all underground coal-mine VAM networks. Engineers must carefully consider these factors when applying the findings to specific mine conditions, as the study itself acknowledges the need for adjustments to account for continuous airflow, network geometry, and site-specific ignition likelihood.
#
#
# (Pro Research Paper): The large-scale detonation-tube experiments described in the paper provide valuable insights into mining ventilation scenarios, but they also establish a foundational understanding that can be adapted to real-world conditions.
#
# 1. **Experimental Conditions**: While the experiments were conducted in a straight cylindrical duct with a diameter of 0.5 m and a length of 30 m, this setup is indeed representative of many mine auxiliary ventilation ducts. The authors note that the stoichiometric test represents the maximum explosion severity that designers must accommodate, which is critical for safety considerations in mine design.
#
# 2. **Static vs. Dynamic Conditions**: Although the tests utilized a static premixed charge, the results still offer a baseline for flame arrester performance. The authors emphasize that the experiments provide realistic flame and pressure data, which can be adjusted for continuous airflow conditions in actual mining operations. This adaptability is crucial for engineers when applying the findings to specific mine conditions.
#
# 3. **Methane Concentrations**: The study tested methane concentrations of 5%, 7.5%, and 9.5%, which bracket conditions that could arise in a VAM return airway. The authors acknowledge that typical return-air methane is often lower than 5%, making the results conservative. This means that while the experiments may over-predict pressure surges, they also ensure that safety measures are robust enough to handle unexpected accumulations.
#
# 4. **Ignition Probability**: The single ignition source used in the experiments does simplify the ignition scenario, but it allows for a controlled evaluation of the flame arrester's performance. The authors recommend that engineers adjust for site-specific ignition likelihoods when applying the findings, ensuring that the design remains resilient against the stochastic nature of ignition in real mines.
#
# In conclusion, while there are limitations in generalizing the results directly to all underground coal-mine VAM networks, the paper provides a solid framework for understanding the effectiveness of inline flame arresters. The findings can be adapted and refined based on specific mine conditions, ensuring that safety and efficiency are maintained in methane abatement strategies.
#
#
#
# ============================================================
# QUESTION 3: What measurement techniques, sensor placements, and statistical or modelling approaches were employed to validate reductions in flame and pressure-wave velocity, and how do these methods align with recognised explosion-safety and methane-control standards?
# ============================================================
# (Moderator): Please address this specific question about the paper 'Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane': What measurement techniques, sensor placements, and statistical or modelling approaches were employed to validate reductions in flame and pressure-wave velocity, and how do these methods align with recognised explosion-safety and methane-control standards?
#
#
# (Con Research Paper): The paper provides a detailed account of the measurement techniques and sensor placements used to validate the performance of inline flame arresters. However, while the methodology appears robust, there are significant concerns regarding its applicability to real-world mining scenarios.
#
# Firstly, the paper employs thirty-three piezo-electric pressure transducers and thirty-three photodiode flame sensors to capture pressure and flame behavior. This setup allows for continuous monitoring along the detonation tube, which is a controlled environment. However, the real-world conditions in underground mines are far more complex, with factors such as high-velocity airflow, bends, and dust deposition that can significantly alter flame and pressure dynamics. The static conditions of the detonation tube do not accurately reflect the dynamic nature of actual mine ventilation systems, which may lead to an overestimation of the flame arrester's effectiveness.
#
# Moreover, while the paper cites alignment with standards such as BS EN 12874: 2001, it does not address the limitations of these standards in high-dust, high-moisture environments typical of coal mines. The potential for coal-dust agglomeration to block arrester channels and increase pressure drop is acknowledged but not sufficiently explored in terms of its impact on operational reliability.
#
# In summary, while the measurement techniques and statistical approaches used in the study are sound, their applicability to real-world mining conditions is questionable. The complexities of underground environments and the limitations of existing standards raise concerns about the practical implementation of flame arresters in mitigating methane explosions in coal mines.
#
#
# (Pro Research Paper): The concerns raised about the applicability of the measurement techniques and sensor placements in the study are valid; however, they overlook the significant strengths and contributions of the research. The paper employs a comprehensive methodology with thirty-three piezo-electric pressure transducers and thirty-three photodiode flame sensors, which provides a robust framework for capturing flame and pressure dynamics in a controlled environment. This setup allows for precise measurements of flame-front and pressure-wave velocities, yielding reductions of up to 44% and 88%, respectively, when using the inline flame arrester (Context).
#
# While it's true that real-world mining conditions are complex, the study's findings provide a critical baseline for understanding the performance of flame arresters under various methane concentrations (5%, 7.5%, and 9.5% CH₄). The experimental setup reflects a worst-case scenario, which is essential for safety design considerations in underground coal mines. The authors themselves acknowledge the need for further research to adapt these findings to dynamic conditions, but the current results still offer valuable insights into the effectiveness of flame arresters in mitigating explosion risks (Context).
#
# Moreover, the alignment with recognized standards such as BS EN 12874: 2001 demonstrates that the study adheres to established performance criteria for flame arresters. The authors also highlight the need for future designs that can operate effectively in high-dust and high-moisture environments, indicating an awareness of the limitations and a commitment to improving the technology (Context).
#
# In conclusion, while the complexities of underground mining environments are acknowledged, the study provides a foundational understanding of flame arrester performance that can guide future research and development. The quantitative data on flame and pressure reductions, combined with adherence to safety standards, underscores the relevance of this research in enhancing safety measures in coal mines.
#
#
#
# ============================================================
# QUESTION 4: Does the study provide data or discussion on pressure-drop penalties, maintenance demands, or capital and operational costs associated with inline flame arresters, and how might these factors influence the economic feasibility of large-scale deployment in VAM systems?
# ============================================================
# (Moderator): Please address this specific question about the paper 'Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane': Does the study provide data or discussion on pressure-drop penalties, maintenance demands, or capital and operational costs associated with inline flame arresters, and how might these factors influence the economic feasibility of large-scale deployment in VAM systems?
#
#
# (Con Research Paper): The study does provide detailed pressure-drop measurements and highlights potential maintenance issues, but it lacks a formal cost analysis. Specifically, the pressure drop across the crimped-ribbon inline arrester increases with methane concentration, reaching about 1.6 bar at 9.5% CH₄. This added pressure drop can exceed the design limits of downstream equipment, necessitating adjustments in plant design (DC-2).
#
# Moreover, the paper notes that coal-dust agglomeration on the arrester surface can lead to extensive pressure drop and blockage, indicating a significant maintenance demand that could require periodic inspection or cleaning (DC-1). However, no specific figures for maintenance schedules, labor, or costs are provided.
#
# The absence of direct cost data for purchase, installation, or operational expenses raises concerns about the economic feasibility of large-scale deployment. Higher pressure losses imply that larger-capacity fans or reinforced ductwork would be needed, increasing capital costs and electricity use. Additionally, the risk of fouling suggests that downtime and labor costs could further elevate operating expenditures.
#
# In summary, while the study emphasizes the safety benefits of inline flame arresters, it does not adequately address the economic implications of their deployment in ventilation-air-methane systems, which could hinder their widespread adoption.
#
#
# (Pro Research Paper): The study indeed highlights significant safety benefits associated with the use of inline flame arresters in ventilation-air-methane (VAM) systems, particularly in terms of explosion mitigation. While it is true that the paper does not provide a formal cost analysis, it does present critical data regarding pressure-drop penalties and maintenance demands that are essential for evaluating the economic feasibility of large-scale deployment.
#
# Firstly, the pressure-drop measurements indicate that the inline flame arrester can lead to an increase in pressure drop, reaching approximately 1.6 bar at 9.5% CH₄ (DC-2). This increase in pressure drop is a crucial factor that must be accounted for in plant design, as it can exceed the design limits of downstream equipment. However, the study emphasizes that despite these pressure losses, the overall explosion pressure is significantly reduced by 50-66%, which is a substantial safety gain (DC-1). This trade-off between safety and pressure drop is vital for decision-makers in the mining sector.
#
# Regarding maintenance demands, the paper acknowledges that coal-dust agglomeration can lead to extensive pressure drop and blockage (DC-1). While it does not provide specific figures for maintenance schedules or costs, the recognition of potential fouling issues indicates that maintenance will be a necessary consideration for operators. This aspect is critical, as it suggests that while there may be initial capital costs associated with the installation of flame arresters, the long-term operational costs could be managed through effective maintenance strategies.
#
# Moreover, the study's findings imply that the safety benefits of flame arresters—such as the complete flame stoppage and significant reductions in flame and pressure-wave velocities—can prevent catastrophic incidents, which could lead to substantial economic losses in the event of an explosion. Therefore, the investment in flame arresters could be justified by the potential savings from avoiding such incidents.
#
# In conclusion, while the paper may not provide explicit cost data, it offers valuable insights into the pressure-drop penalties and maintenance demands associated with inline flame arresters. The safety benefits, coupled with the potential for reduced catastrophic risk, suggest that the deployment of these devices could be economically feasible in the long run, especially when considering the critical need for enhanced safety in underground coal mines. Thus, the study is highly relevant to the research of G-MAST STAGE PAYLOAD, as it aligns with the overarching goal of improving safety and efficiency in mining operations.
#
#
#
# ============================================================
# QUESTION 5: Given the observed upstream pressure build-up when a flame arrester is installed, what design adaptations or process-control strategies does the paper recommend to prevent adverse impacts on plant integrity and continuous methane-oxidation efficiency?
# ============================================================
# (Moderator): Please address this specific question about the paper 'Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane': Given the observed upstream pressure build-up when a flame arrester is installed, what design adaptations or process-control strategies does the paper recommend to prevent adverse impacts on plant integrity and continuous methane-oxidation efficiency?
#
#
# (Con Research Paper): The paper recommends several design adaptations and process-control strategies to mitigate the adverse impacts of upstream pressure build-up caused by the installation of an inline flame arrester. These include:
#
# 1. **Increasing the Allowed Design Pressure of Up-Stream Equipment**: The authors emphasize that the pressure in front of the arrester can exceed values seen in a smooth duct, particularly at higher methane concentrations. Therefore, it is crucial to specify piping, ducts, isolation valves, and the oxidiser inlet for higher transient over-pressures to ensure mechanical integrity.
#
# 2. **Selecting or Developing Flame Arresters with Lower Intrinsic Pressure Drop**: The study suggests future development of flame arresters that have substantially lower pressure drops to avoid restricting normal ventilation-air flow to the thermal oxidiser.
#
# 3. **Mitigating Dust and Moisture Blockage**: The paper warns that coal dust can coat the arrester element, increasing differential pressure and potentially causing blockage. Design adaptations, such as self-cleaning elements or larger free areas, are recommended to accommodate the moist, dusty conditions typical in mines.
#
# 4. **Carrying Out Full-Scale Experimental Verification for Each Installation**: Before starting the plant, the entire system should be tested under expected methane concentrations to confirm that pressure peaks and drops remain within revised design limits.
#
# 5. **Implementing Robust Process-Control Monitoring**: Continuous monitoring of line pressure, differential pressure across the arrester, and methane concentration is advised to detect abnormal pressure rises early, allowing for adjustments to maintain oxidation efficiency and protect equipment.
#
# These recommendations highlight the need for careful design and operational strategies to ensure that the benefits of flame arresters in enhancing explosion safety do not compromise the integrity and efficiency of methane oxidation systems in coal mines.
#
#
# (Pro Research Paper): The recommendations provided in the paper for addressing upstream pressure build-up when installing an inline flame arrester are crucial for ensuring both safety and operational efficiency in methane oxidation systems.
#
# 1. **Increasing the Allowed Design Pressure of Up-Stream Equipment**: The paper emphasizes that the pressure in front of the arrester can rise significantly, especially at higher methane concentrations, necessitating that all related equipment be rated for these higher transient pressures. This adaptation is essential to prevent mechanical failures that could compromise safety (Context).
#
# 2. **Selecting or Developing Flame Arresters with Lower Intrinsic Pressure Drop**: The authors advocate for the development of flame arresters that exhibit lower pressure drops. This is vital to maintain normal ventilation-air flow to the thermal oxidiser, thereby ensuring continuous operation without excessive pressure loss (Context).
#
# 3. **Mitigating Dust and Moisture Blockage**: The potential for coal dust to agglomerate on the arrester surface, leading to increased pressure drop and blockage, is a significant concern. The paper suggests design adaptations such as self-cleaning elements to address this issue, which is particularly relevant in the dusty environments of coal mines (Context).
#
# 4. **Carrying Out Full-Scale Experimental Verification for Each Installation**: The recommendation to conduct full-scale tests under expected methane concentrations ensures that the system's performance aligns with safety and operational standards, confirming that pressure peaks remain within acceptable limits (Context).
#
# 5. **Implementing Robust Process-Control Monitoring**: Continuous monitoring is critical for early detection of abnormal pressure rises, allowing for timely adjustments to maintain methane oxidation efficiency and protect equipment integrity (Context).
#
# These strategies collectively enhance the safety and reliability of methane oxidation systems in coal mines, demonstrating the paper's relevance to ongoing research and development in explosion mitigation technologies. The focus on balancing safety improvements with operational efficiency aligns with the overarching goal of reducing methane emissions in the mining sector.
#
#
#
# ============================================================
# QUESTION 6: How does the paper situate flame arresters relative to alternative explosion-mitigation options (e.g., fast-acting isolation valves, passive vents, inerting systems) in terms of effectiveness, cost, and compatibility with VAM oxidisers?
# ============================================================
# (Moderator): Please address this specific question about the paper 'Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane': How does the paper situate flame arresters relative to alternative explosion-mitigation options (e.g., fast-acting isolation valves, passive vents, inerting systems) in terms of effectiveness, cost, and compatibility with VAM oxidisers?
#
#
# (Con Research Paper): The paper primarily focuses on the inline flame arrester as the only option with experimentally demonstrated performance in mitigating explosions in ventilation air methane (VAM) systems. While it acknowledges other alternatives like fast-acting isolation valves and passive vents, it does not provide any quantitative data or comparative analysis for these options. This lack of empirical evidence raises concerns about the reliability of the alternatives mentioned.
#
# In terms of effectiveness, the flame arrester has shown significant results, such as stopping flame fronts for various methane concentrations and reducing pressure-wave velocities by up to 88%. However, the paper does not benchmark these results against the performance of other technologies, leaving a gap in understanding how they might compare in real-world applications.
#
# Regarding costs, the paper fails to present any financial data for the flame arrester or the alternative options. It highlights that the pressure drop associated with the flame arrester can lead to increased capital costs due to the need for larger fans and reinforced ductwork. This economic burden is crucial for large-scale deployment, yet no cost analysis is provided for the alternatives, making it difficult to assess their feasibility.
#
# Compatibility with VAM thermal oxidisers is explicitly discussed for the flame arrester, which is designed to handle the specific conditions of VAM streams. In contrast, the paper does not evaluate how well the alternative options would integrate with VAM systems, leaving a significant gap in understanding their practical application.
#
# In summary, while the paper provides valuable insights into the performance of flame arresters, it does not adequately address the effectiveness, costs, or compatibility of alternative explosion-mitigation options, which are critical for making informed decisions in the field. This lack of comprehensive analysis suggests that relying solely on flame arresters without considering other viable options may not be the most prudent approach for enhancing safety in VAM systems.
#
#
# (Pro Research Paper): The paper "Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane" provides a focused and empirical examination of inline flame arresters, which are crucial for enhancing safety in ventilation air methane (VAM) systems. While it acknowledges other explosion-mitigation options, it is important to emphasize that the flame arrester is the only technology whose performance has been experimentally validated within the context of VAM systems.
#
# In terms of effectiveness, the paper demonstrates that the inline flame arrester successfully stops flame fronts for methane concentrations of 5%, 7.5%, and 9.5%, achieving a reduction in pressure-wave velocity by up to 88% and flame-front velocity by approximately 32-44%. These results are significant and provide a clear safety advantage, which is not matched by the alternatives mentioned, as no quantitative data or performance benchmarks for those options are provided in the study.
#
# Regarding costs, while the paper does not present specific financial data, it highlights the implications of pressure drop associated with the flame arrester, which can necessitate larger-capacity fans and reinforced ductwork. This is a critical consideration for large-scale deployment, and the authors suggest that the benefits of enhanced safety must be weighed against these potential economic burdens. The lack of cost analysis for alternative options further underscores the need for a comprehensive understanding of their feasibility, which the paper does not provide.
#
# Compatibility with VAM thermal oxidisers is explicitly addressed for the flame arrester, which is designed to withstand the specific conditions of VAM streams, including dust and moisture. In contrast, the paper does not evaluate how well alternative options would integrate with VAM systems, leaving a gap in understanding their practical application.
#
# In conclusion, the paper's focus on the inline flame arrester, supported by empirical data, positions it as a vital component for explosion mitigation in VAM systems. While alternative options are acknowledged, their lack of experimental validation and cost analysis limits their reliability and applicability. Therefore, the flame arrester remains a critical tool for enhancing safety in mining environments, and its adoption should be prioritized based on the evidence presented.
#
#
#
# ============================================================
# QUESTION 7: What regulatory standards, certification procedures, or policy incentives are discussed for integrating flame arresters into methane-abatement infrastructure in coal mines, and what gaps remain for widespread adoption?
# ============================================================
# (Moderator): Please address this specific question about the paper 'Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane': What regulatory standards, certification procedures, or policy incentives are discussed for integrating flame arresters into methane-abatement infrastructure in coal mines, and what gaps remain for widespread adoption?
#
#
# (Con Research Paper): The paper discusses several regulatory standards and certification procedures relevant to integrating flame arresters into methane-abatement infrastructure in coal mines. Key points include:
#
# 1. **Mine-safety regulations** mandate that underground coal-mine ventilation air must be kept below **1.25% CH₄** to prevent fire and explosion risks, which directly influences the design and deployment of safety devices like flame arresters.
#
# 2. **BS EN 12874: 2001** outlines performance requirements and testing methods for flame arresters, serving as a benchmark for certification. However, concerns have been raised about its adequacy under certain operating conditions, indicating a need for further research.
#
# 3. The **Maximum Experimental Safety Gap (MESG)** is a critical design parameter for flame arresters, ensuring that channel sizes are appropriate for methane, as demonstrated in the experiments.
#
# 4. The **API Committee on Safety and Fire Protection** develops industry standards and reviews failures of inline arresters, providing best-practice guidance for operators.
#
# Despite these frameworks, the paper identifies several gaps that hinder widespread adoption:
#
# 1. **Scenario-specific certification** is lacking, particularly for high-dust and high-moisture environments where coal-dust agglomeration can block arrester channels, increasing pressure drop and failure risks.
#
# 2. There is insufficient guidance on managing **pressure build-up** downstream of arresters, which can sharply rise, especially at stoichiometric CH₄ levels.
#
# 3. Current standards do not adequately address **in-situ performance monitoring or maintenance schedules**, despite documented failures in the field.
#
# 4. There is a lack of **global harmonization** in standards, leading to varying acceptance criteria across jurisdictions.
#
# 5. **Incentive coverage** for routine installations of flame arresters in mine ventilation systems is limited, with funding schemes primarily focused on research rather than operational deployment.
#
# In summary, while there are regulatory frameworks in place, significant gaps remain in adapting these standards to specific mining conditions and ensuring economic incentives for widespread adoption of flame arresters in methane-abatement systems.
#
#
# (Pro Research Paper): The paper "Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane" provides a comprehensive overview of the regulatory standards, certification procedures, and policy incentives necessary for integrating flame arresters into methane-abatement infrastructure in coal mines.
#
# 1. **Mine-safety regulations** are crucial, as they mandate that underground coal-mine ventilation air must be kept below **1.25% CH₄** to mitigate fire and explosion risks. This regulation directly influences the design and mandatory deployment of safety devices like flame arresters, ensuring that they are integrated into ventilation systems to maintain compliance and enhance safety.
#
# 2. The **BS EN 12874: 2001** standard outlines performance requirements and testing methods for flame arresters, serving as a benchmark for certification. This standard is widely recognized in the industry, but the paper notes concerns regarding its adequacy under certain operating conditions, highlighting the need for further research to ensure that flame arresters perform effectively in all scenarios.
#
# 3. The **Maximum Experimental Safety Gap (MESG)** is another critical design parameter that ensures the channel sizes of flame arresters are appropriate for methane, as demonstrated in the experiments. This parameter is essential for the safe operation of flame arresters in mining environments.
#
# 4. The **API Committee on Safety and Fire Protection** plays a vital role in developing industry standards and reviewing failures of inline arresters, providing best-practice guidance for operators. This oversight is crucial for maintaining safety and effectiveness in methane-abatement systems.
#
# Despite these frameworks, the paper identifies several gaps that hinder widespread adoption:
#
# 1. **Scenario-specific certification** is lacking, particularly for high-dust and high-moisture environments where coal-dust agglomeration can block arrester channels, increasing pressure drop and failure risks. This gap indicates that existing standards may not fully account for the unique challenges faced in underground mining conditions.
#
# 2. There is insufficient guidance on managing **pressure build-up** downstream of arresters, which can sharply rise, especially at stoichiometric CH₄ levels. This lack of guidance can lead to safety risks if not properly addressed in design and operational practices.
#
# 3. Current standards do not adequately address **in-situ performance monitoring or maintenance schedules**, despite documented failures in the field. This oversight can result in unanticipated failures and safety hazards if regular monitoring and maintenance are not enforced.
#
# 4. There is a lack of **global harmonization** in standards, leading to varying acceptance criteria across jurisdictions. This inconsistency can complicate the deployment of flame arresters in international operations.
#
# 5. **Incentive coverage** for routine installations of flame arresters in mine ventilation systems is limited, with funding schemes primarily focused on research rather than operational deployment. This limitation can hinder the economic feasibility of integrating flame arresters into existing systems.
#
# In summary, while the paper outlines important regulatory frameworks and standards, it also highlights significant gaps that must be addressed to facilitate the widespread adoption of flame arresters in methane-abatement systems in coal mines. These gaps include the need for scenario-specific certifications, better pressure management guidelines, and enhanced monitoring and maintenance protocols.
#
#
# ================================================================================
# DEBATE COMPLETED - ALL QUESTIONS ADDRESSED
# ================================================================================
#
# Debate results captured in structured format!
# Total questions: 7
# Total agent responses: 14

# %%
# Save debate results for judges system
import json

# Save as JSON file
with open("debate_results.json", "w") as f:
    f.write(debate_results.to_json())

print("✅ Debate results saved to debate_results.json")

# Example: Access specific question responses
print("\n" + "="*50)
print("EXAMPLE: Accessing structured data")
print("="*50)

# Get responses for question 1
q1_debate = debate_results.get_question_responses(1)
if q1_debate:
    print(f"Question 1: {q1_debate.question_text[:100]}...")
    print(f"Number of responses: {len(q1_debate.agent_responses)}")
    for response in q1_debate.agent_responses:
        print(f"- {response.agent_name}: {response.response[:150]}...")

# Get all responses from Pro agent
pro_responses = debate_results.get_agent_responses("Pro Research Paper")
print(f"\nPro Research Paper made {len(pro_responses)} responses total")

print("\n" + "="*50)
print("Ready for judges system! 🏛️")
print("="*50)
# Out:
# ✅ Debate results saved to debate_results.json
#
# ==================================================
# EXAMPLE: Accessing structured data
# ==================================================
# Question 1: In what way does adding the inline flame arrester change the overall methane-destruction performance...
# Number of responses: 2
# - Con Research Paper: The addition of an inline flame arrester does enhance explosion safety significantly, as it can completely stop flames and reduce flame speeds and pre...
# - Pro Research Paper: The inline flame arrester indeed enhances explosion safety significantly while maintaining methane-destruction efficiency. The study demonstrates that...
#
# Pro Research Paper made 7 responses total
#
# ==================================================
# Ready for judges system! 🏛️
# ==================================================

# %% [markdown]
# ---
# ---
#
# # Jury

# %%
from judges_panel import evaluate_paper, JUDGES

# %%
print("🏛️ JUDGES PANEL EVALUATION")
print("="*60)
print(f"Panel composition: {len(JUDGES)} judges")
for judge in JUDGES:
    print(f"  - {judge.id}: {judge.role} ({judge.model_name})")
print()

# Extract context chunks from your context dictionary
context_chunks = []
for question, answer in context.items():
    context_chunks.append(f"Q: {question}\nA: {answer}")

# Run the full evaluation
print("⚖️  Starting comprehensive evaluation...")
paper_evaluation = evaluate_paper(debate_results, context_chunks)

print("\n" + "="*60)
print("📊 FINAL PAPER EVALUATION RESULTS")
print("="*60)
print(f"Paper: {paper_evaluation.paper_title}")
print(f"Overall Relevance: {paper_evaluation.overall_relevance.upper()}")
print(f"Pro Arguments Won: {paper_evaluation.pro_wins} questions")
print(f"Con Arguments Won: {paper_evaluation.con_wins} questions") 
print(f"Ties: {paper_evaluation.ties} questions")
print(f"Average Pro Score: {paper_evaluation.avg_pro_score}/10")
print(f"Average Con Score: {paper_evaluation.avg_con_score}/10")
print()
print("Summary:")
print(paper_evaluation.summary)

# Save complete evaluation results
with open("paper_evaluation.json", "w") as f:
    f.write(paper_evaluation.model_dump_json(indent=2))
    
print("\n✅ Complete evaluation saved to paper_evaluation.json")
print("🎯 Ready for decision-making pipeline!")
# Out:
# 🏛️ JUDGES PANEL EVALUATION
# ============================================================
# Panel composition: 5 judges
#   - J1: Methods (gpt-4.1-2025-04-14)
#   - J2: Regulatory (gpt-5-2025-08-07)
#   - J3: TechnoEcon (gpt-4o)
#   - J4: Applicability (o3-2025-04-16)
#   - J5: Skeptic (o4-mini-2025-04-16)
#
# ⚖️  Starting comprehensive evaluation...
# 🏛️ Starting Judge Panel Evaluation...
# 📋 Evaluating 7 questions
# ⚖️  Judging Question 1/7
#    Winner: Pro | Relevance: relevant
# ⚖️  Judging Question 2/7
#    Winner: Con | Relevance: relevant
# ⚖️  Judging Question 3/7
#    Winner: Pro | Relevance: relevant
# ⚖️  Judging Question 4/7
#    Winner: Con | Relevance: relevant
# ⚖️  Judging Question 5/7
#    Winner: tie | Relevance: borderline
# ⚖️  Judging Question 6/7
#    Winner: Pro | Relevance: relevant
# ⚖️  Judging Question 7/7
#    Winner: Pro | Relevance: relevant
#
# ============================================================
# 📊 FINAL PAPER EVALUATION RESULTS
# ============================================================
# Paper: Application of flame arrester in mitigation of explosion and flame deflagration of ventilation air methane
# Overall Relevance: RELEVANT
# Pro Arguments Won: 4 questions
# Con Arguments Won: 2 questions
# Ties: 1 questions
# Average Pro Score: 8.4/10
# Average Con Score: 7.86/10
#
# Summary:
# Paper evaluation completed with 7 questions judged. Pro arguments won 4 questions, Con won 2, with 1 ties. Average scores: Pro 8.4/10, Con 7.9/10. Overall relevance assessment: relevant. Questions rated as relevant: 6, borderline: 1.
#
# ✅ Complete evaluation saved to paper_evaluation.json
# 🎯 Ready for decision-making pipeline!

# %% [markdown]
# ---
# ---
# # Misc.

# %% [markdown]
# ## Reading Entire Doc

# %%
from langchain_community.document_loaders import PyPDFLoader
import glob

async def read_pdf(file_path):
    loader = PyPDFLoader(file_path)
    pages = []
    async for page in loader.alazy_load():
        pages.append(page)
    return pages



files = glob.glob("/Users/ishaankalra/Dev/CGS/debaccle/papers/*.pdf")

docs = []
for file in files:
    print("Reading file: ", file)
    output = await read_pdf(file)
    # print(output)
    docs.append(output)

print(docs)
